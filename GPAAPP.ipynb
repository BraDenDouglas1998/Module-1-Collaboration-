# %%
#Bra'Den Douglas
#GPA APP
#This will allow you to enter student names and check if they have made honor roll or deans list.
while True:
    last_name = input("Enter student's last name (or 'ZZZ' to quit): ").strip()
    if last_name.upper() == 'ZZZ':
        print("Complete.")
        break
    first_name = input("Enter student's first name: ").strip()
    gpa = float(input("Enter student's GPA: "))
    if gpa >= 3.25:
        print(f"{first_name} {last_name} made the Dean's list!")
    elif gpa >= 3.25:
        print(f"{first_name} {last_name} made the Honor Roll!")
    else:
        print(f"{first_name} {last_name} did not make either.")
# Out:
# Enter student's last name (or 'ZZZ' to quit):  Thomas
# Enter student's first name:  Jason
# Enter student's GPA:  3.25
# Jason Thomas made the Dean's list!
# Enter student's last name (or 'ZZZ' to quit):  Douglas
# Enter student's first name:  Douglas
# Enter student's GPA:  3.5
# Douglas Douglas made the Dean's list!
# Enter student's last name (or 'ZZZ' to quit):  Fredrick
# Enter student's first name:  Fredricka
# Enter student's GPA:  3.25
# Fredricka Fredrick made the Dean's list!
# Enter student's last name (or 'ZZZ' to quit):  Snoobert
# Enter student's first name:  Goobert
# Enter student's GPA:  3.10
# Goobert Snoobert did not make either.
# Enter student's last name (or 'ZZZ' to quit):  Burger
# Enter student's first name:  Turkey
# Enter student's GPA:  3.0
# Turkey Burger did not make either.
# Enter student's last name (or 'ZZZ' to quit):  Zeider
# Enter student's first name:  Morgan
# Enter student's GPA:  3.5
# Morgan Zeider made the Dean's list!
# ...

# %%
things = ["mozzarella", "cinderella", "salmonella"]
things[1] = things[1].capitalize()
things[0] = things[0].capitalize()   #It did change the things in the list.
print(things)
# Out:
# ['Mozzarella', 'Cinderella', 'salmonella']

# %%
del things[2]
print(things)
# Out:
# ['Mozzarella', 'Cinderella']

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']
result = good()
print(result)
# Out:
# ['Harry', 'Ron', 'Hermione']
